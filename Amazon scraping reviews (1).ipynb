# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
pages = [
    "https://www.amazon.fr/Reebok-Clean-Baskets-Basses-gar%C3%A7on/product-reviews/B01BOSHA18/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews",
    "https://www.amazon.fr/Reebok-Clean-Baskets-Basses-gar%C3%A7on/product-reviews/B01BOSHA18/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2",
    "https://www.amazon.fr/Reebok-Clean-Baskets-Basses-gar%C3%A7on/product-reviews/B01BOSHA18/ref=cm_cr_getr_d_paging_btm_next_3?ie=UTF8&reviewerType=all_reviews&pageNumber=3"
]

headers = {
    'authority': 'www.amazon.fr',
    'cache-control': 'max-age=0',
    'rtt': '50',
    'downlink': '10',
    'ect': '4g',
    'sec-ch-ua': '^\\^',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://www.amazon.fr/Reebok-Baskets-Basses-AR3169_39-EU_White/dp/B01IY4FSV4/ref=sr_1_10?keywords=Basket&pd_rd_r=35c40ee9-6426-4dc7-8609-d54fd9e8df6b&pd_rd_w=JE15w&pd_rd_wg=1XaYJ&pf_rd_p=812ce82e-1ac3-4b65-8f33-c18ddb118c9b&pf_rd_r=HTJES7VVAJY4BD3H6VSS&qid=1643147321&refinements=p_n_format_browse-bin^%^3A13331152031^%^2Cp_89^%^3AReebok&rnid=1680780031&s=shoes&sr=1-10&th=1',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'session-id=258-2502799-4774719; i18n-prefs=EUR; ubid-acbfr=262-2657426-8673217; lc-acbfr=fr_FR; session-token=5CFf8bSBFeG7NljDWfbt6+e6qlzAvjrzs8aLigv9OGHwgy1irEeP3J/ce26431gbF+tc9JTo3BSFx7rUQdIvalOUA9C22Sbi9RAlqVgO+41Wr7w5giEgiXU1QPbobSK0gayKXKLT95ay/zQ6xvjfJLDgGDaTns3opy7ipohSPDg8uez7+J0WmNflYGcCGfeH; session-id-time=2082787201l; csm-hit=tb:XTC31K1GH4384PAYZGM8+sa-PB0VH6FF6RGFE1YCCXVH-F680KP0JAVSS2W59S23X^|1643152308690&t:1643152308690&adb:adblk_no',
}

# %%
resp = requests.get(pages[0], headers=headers)
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!doctype html><html lang="fr-fr" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.
# ...

# %%
soup = BeautifulSoup(resp.text, "html.parser")

# %%
reviews = soup.find_all("div", {"class":"a-section review aok-relative"})

# %%
len(reviews)
# Out:
# 10

# %%
def get_review_stars(soup_obj: BeautifulSoup) -> str:
    try:
        review_str = soup_obj.find('a', {"class": "a-link-normal"}).get_text()
        return review_str
    except Exception as e:
        return 'no_stars'
        print(e)

# %%
def get_review_body(soup_obj: BeautifulSoup) -> str:
    try:
        review_body = soup_obj.find('span', 
            {"class": "a-size-base review-text review-text-content"}
        ).get_text().strip()
        return review_body
    except Exception as e:
        return 'no_body'
        print(e)

# %%
def get_review_date(soup_obj: BeautifulSoup) -> str:
    try:
        review_date = soup_obj.find('span', 
            {"class": "a-size-base a-color-secondary review-date"}
        ).get_text().strip()
        return review_date
    except Exception as e:
        return 'no_date'
        print(e)

# %%
def get_review_components(soup_obj: BeautifulSoup) -> dict:
    return {
        'stars': get_review_stars(soup_obj) , 
        'body': get_review_body(soup_obj), 
        'date': get_review_date(soup_obj)
    }

# %%
records = [get_review_components(rev) for rev in reviews]
df = pd.DataFrame.from_records(records)
df.to_csv('amazon_reviews.csv')

# %%
ALL_REVIEWS = []

for u in pages:
    print(u)
    resp = requests.get(u, headers=headers)
    soup = BeautifulSoup(resp.text, "html.parser")
    reviews = soup.find_all("div", {"class": "a-section review aok-relative"})
    records = [get_review_components(rev) for rev in reviews]
    ALL_REVIEWS.extend(records) 
    
    
out = pd.DataFrame.from_records(ALL_REVIEWS)
out.head()
# Out:
# https://www.amazon.fr/Reebok-Clean-Baskets-Basses-gar%C3%A7on/product-reviews/B01BOSHA18/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# https://www.amazon.fr/Reebok-Clean-Baskets-Basses-gar%C3%A7on/product-reviews/B01BOSHA18/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.fr/Reebok-Clean-Baskets-Basses-gar%C3%A7on/product-reviews/B01BOSHA18/ref=cm_cr_getr_d_paging_btm_next_3?ie=UTF8&reviewerType=all_reviews&pageNumber=3
#                stars                                               body  \
# 0  5,0 sur 5 étoiles  Chaussures très confortables et passe partout ...
# 1  5,0 sur 5 étoiles  Je porte ces Reebok Ex-O-Fit au quotidien, en ...
# 2  5,0 sur 5 étoiles  cet achat était pour remplacer mes baskets de ...
# 3  4,0 sur 5 étoiles  au vue des commentaires  j ai commandé une tai...
# 4  3,0 sur 5 étoiles  La taille est un peu juste, mais avec l'utilis...
#
#                                     date
# ...

# %%
from datetime import datetime

# %%
save_name = f"{datetime.now().strftime('%Y-%m-%d')}.csv"
save_name
# Out:
# '2022-01-26.csv'
